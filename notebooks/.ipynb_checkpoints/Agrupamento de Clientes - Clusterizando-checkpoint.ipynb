# %%
import pandas as pd
import datetime
from minio import Minio

import sys
sys.path.append(r'D:\Documentos\Projetos\Ollist_End_to_End\airflow\dags')
import functions as f

# %%
data_lake_server= f.var['data_lake_server_local']
data_lake_login= f.var['data_lake_login']
data_lake_password= f.var['data_lake_password']

client = Minio(
        endpoint= data_lake_server,
        access_key= data_lake_login,
        secret_key= data_lake_password,
        secure=False
    )

# %%
df_rfm = pd.read_parquet(
    f.read_minio_file(bucket_name= 'agrupamento-clientes', file= 'dataframe_rfm.parquet', client= client)
)

# %%
df_rfm.head()
# Out:
#                  customer_unique_id  geolocation_lat  geolocation_lng  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2       -23.340328       -46.830141
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f       -23.559115       -46.787626
# 2  0000f46a3911fa3c0805444483337064       -27.542820       -48.633051
# 3  0000f6ccb0745a6a4b88665a16c9f078        -1.313018       -48.483798
# 4  0004aac84e0df4da2b147fca70cf8255       -23.505548       -47.469705
#
#    frequency  monetary  recency
# 0          1    129.90    115.0
# 1          1     18.90    118.0
# 2          1     69.00    541.0
# 3          1     25.99    325.0
# 4          1    180.00    292.0

# %%
from pycaret.clustering import *

exp_clu101 = setup(data= df_rfm, normalize = True, 
                   ignore_features = ['customer_unique_id'],
                   session_id = 123)
# Out:
# <style  type="text/css" >
# #T_69e35_row2_col1,#T_69e35_row21_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_69e35_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69e35_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_69e35_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_69e35_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_69e35_row1_col0" class="data row1 col0" >Original Data</td>
#                         <td id="T_69e35_row1_col1" class="data row1 col1" >(96096, 6)</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_69e35_row2_col0" class="data row2 col0" >Missing Values</td>
#                         <td id="T_69e35_row2_col1" class="data row2 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_69e35_row3_col0" class="data row3 col0" >Numeric Features</td>
#                         <td id="T_69e35_row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_69e35_row4_col0" class="data row4 col0" >Categorical Features</td>
#                         <td id="T_69e35_row4_col1" class="data row4 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_69e35_row5_col0" class="data row5 col0" >Ordinal Features</td>
#                         <td id="T_69e35_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_69e35_row6_col0" class="data row6 col0" >High Cardinality Features</td>
#                         <td id="T_69e35_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_69e35_row7_col0" class="data row7 col0" >High Cardinality Method</td>
#                         <td id="T_69e35_row7_col1" class="data row7 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_69e35_row8_col0" class="data row8 col0" >Transformed Data</td>
#                         <td id="T_69e35_row8_col1" class="data row8 col1" >(96096, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_69e35_row9_col0" class="data row9 col0" >CPU Jobs</td>
#                         <td id="T_69e35_row9_col1" class="data row9 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_69e35_row10_col0" class="data row10 col0" >Use GPU</td>
#                         <td id="T_69e35_row10_col1" class="data row10 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_69e35_row11_col0" class="data row11 col0" >Log Experiment</td>
#                         <td id="T_69e35_row11_col1" class="data row11 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_69e35_row12_col0" class="data row12 col0" >Experiment Name</td>
#                         <td id="T_69e35_row12_col1" class="data row12 col1" >cluster-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_69e35_row13_col0" class="data row13 col0" >USI</td>
#                         <td id="T_69e35_row13_col1" class="data row13 col1" >2aae</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_69e35_row14_col0" class="data row14 col0" >Imputation Type</td>
#                         <td id="T_69e35_row14_col1" class="data row14 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_69e35_row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_69e35_row15_col1" class="data row15 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_69e35_row16_col0" class="data row16 col0" >Numeric Imputer</td>
#                         <td id="T_69e35_row16_col1" class="data row16 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_69e35_row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_69e35_row17_col1" class="data row17 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_69e35_row18_col0" class="data row18 col0" >Categorical Imputer</td>
#                         <td id="T_69e35_row18_col1" class="data row18 col1" >mode</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_69e35_row19_col0" class="data row19 col0" >Iterative Imputation Categorical Model</td>
#                         <td id="T_69e35_row19_col1" class="data row19 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_69e35_row20_col0" class="data row20 col0" >Unknown Categoricals Handling</td>
#                         <td id="T_69e35_row20_col1" class="data row20 col1" >least_frequent</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_69e35_row21_col0" class="data row21 col0" >Normalize</td>
#                         <td id="T_69e35_row21_col1" class="data row21 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_69e35_row22_col0" class="data row22 col0" >Normalize Method</td>
#                         <td id="T_69e35_row22_col1" class="data row22 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_69e35_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_69e35_row23_col0" class="data row23 col0" >Transformation</td>
#                         <td id="T_69e35_row23_col1" class="data row23 col1" >False</td>
#             </tr>
#             <tr>

# %%
kmeans = create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0       0.306         32787.0702          1.0665            0           0
#
#    Completeness
# 0             0

# %%
evaluate_model(kmeans)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Cluster PCA Plot (2d)', …
